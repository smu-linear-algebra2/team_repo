# %% [markdown]
# <a href="https://colab.research.google.com/github/smu-linear-algebra2/hs/blob/main/3%EC%A3%BC%EC%B0%A8_%EC%8B%A4%EC%8A%B514.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.array([2,1])
b = np.array([-3,2])

fig = plt.figure()
ax = fig.add_subplot(1,1,1)

# 벡터a를 그린다.
ax.quiver(0,0,a[0],a[1], angles='xy', scale_units='xy', scale=1)
ax.text(a[0], a[1], 'a', size=15)

# 벡터b를 그린다.
ax.quiver(0,0,b[0],b[1], angles='xy', scale_units='xy', scale=1)
ax.text(b[0],b[1], 'b', size=15)

ax.set_xticks(range(-5,4))
ax.set_yticks(range(-2,6))
ax.grid()
ax.set_axisbelow(True)
ax.set_aspect('auto', adjustable='box')
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.show()
